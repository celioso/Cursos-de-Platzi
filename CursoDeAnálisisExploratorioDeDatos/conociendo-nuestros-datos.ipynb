# %% [markdown]
# # Conociendo nuestros datos de pingüinos. 🗺🧭🐧

# %% [markdown]
# ## Instalar librerías necesarias

# %% [markdown]
# ```
# !pip install --upgrade pip
# ```
# ```
# !pip install palmerpenguins==0.1.4 numpy==1.23.4 pandas==1.5.1 seaborn==0.12.1 matplotlib==3.6.0 empiricaldist==0.6.7 statsmodels==0.13.5 scikit-learn==1.1.2 pyjanitor==0.23.1 session-info
# ```

# %% [markdown]
# ## Importar librerías

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (22.0.4)
# Collecting pip
#   Downloading pip-23.1.2-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.8 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# Successfully installed pip-23.1.2

# %%
pip Uninstalling MarkupSafe
# Out:
# ERROR: unknown command "Uninstalling" - maybe you meant "uninstall"
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install palmerpenguins numpy pandas seaborn matplotlib empiricaldist statsmodels scikit-learn janitor session-info ConfigParser pyjanitor
# Out:
# Requirement already satisfied: palmerpenguins in /root/venv/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: numpy in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.23.4)
# Requirement already satisfied: pandas in /root/venv/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: seaborn in /shared-libs/python3.9/py/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: empiricaldist in /root/venv/lib/python3.9/site-packages (0.6.7)
# Requirement already satisfied: statsmodels in /root/venv/lib/python3.9/site-packages (0.13.5)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.1.2)
# Collecting janitor
#   Downloading Janitor-0.1.1.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: session-info in /root/venv/lib/python3.9/site-packages (1.0.0)
# Collecting ConfigParser
#   Downloading configparser-5.3.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyjanitor in /root/venv/lib/python3.9/site-packages (0.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas) (2022.5)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: patsy>=0.5.2 in /root/venv/lib/python3.9/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Collecting Flask
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 KB 21.1 MB/s eta 0:00:00
# Collecting gevent
#   Downloading gevent-22.10.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 69.4 MB/s eta 0:00:00
# Collecting wsgi-oauth2
#   Downloading wsgi_oauth2-0.2.2-py2.py3-none-any.whl (9.4 kB)
# Requirement already satisfied: stdlib-list in /root/venv/lib/python3.9/site-packages (from session-info) (0.8.0)
# Requirement already satisfied: multipledispatch in /root/venv/lib/python3.9/site-packages (from pyjanitor) (0.6.0)
# Requirement already satisfied: pandas-flavor in /root/venv/lib/python3.9/site-packages (from pyjanitor) (0.5.0)
# Requirement already satisfied: natsort in /root/venv/lib/python3.9/site-packages (from pyjanitor) (8.3.1)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Collecting itsdangerous>=2.1.2
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: click>=8.1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from Flask->janitor) (8.1.3)
# Collecting Werkzeug>=2.3.3
#   Downloading Werkzeug-2.3.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 KB 49.8 MB/s eta 0:00:00
# Collecting Jinja2>=3.1.2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from Flask->janitor) (5.0.0)
# Requirement already satisfied: zope.interface in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gevent->janitor) (5.5.0)
# Collecting greenlet>=2.0.0
#   Downloading greenlet-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (610 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 610.9/610.9 KB 80.5 MB/s eta 0:00:00
# Collecting zope.event
#   Downloading zope.event-4.6-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from gevent->janitor) (58.1.0)
# Requirement already satisfied: xarray in /root/venv/lib/python3.9/site-packages (from pandas-flavor->pyjanitor) (2023.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /root/venv/lib/python3.9/site-packages (from pandas-flavor->pyjanitor) (0.2)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->Flask->janitor) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from Jinja2>=3.1.2->Flask->janitor) (2.0.0)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Building wheels for collected packages: janitor
#   Building wheel for janitor (setup.py) ... done
#   Created wheel for janitor: filename=Janitor-0.1.1-py3-none-any.whl size=3828 sha256=4cc0ecba9b058da2b9634623544ee32f2a78ac57a426197365c6b45da13a1452
#   Stored in directory: /root/.cache/pip/wheels/61/61/a6/bd3a0f4cf7fca2b6cc2a2adbd97beec73a9039cf358b761d41
# Successfully built janitor
# Installing collected packages: zope.event, wsgi-oauth2, MarkupSafe, itsdangerous, greenlet, ConfigParser, blinker, Werkzeug, Jinja2, gevent, Flask, janitor
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.0
#     Not uninstalling markupsafe at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 1.1.3.post0
#     Not uninstalling greenlet at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'greenlet'. No files were found to uninstall.
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.2.2
#     Not uninstalling werkzeug at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'Werkzeug'. No files were found to uninstall.
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Not uninstalling jinja2 at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'Jinja2'. No files were found to uninstall.
# Successfully installed ConfigParser-5.3.0 Flask-2.3.2 Jinja2-3.1.2 MarkupSafe-2.1.2 Werkzeug-2.3.4 blinker-1.6.2 gevent-22.10.2 greenlet-2.0.2 itsdangerous-2.1.2 janitor-0.1.1 wsgi-oauth2-0.2.2 zope.event-4.6
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
pip install palmerpenguins==0.1.4 numpy==1.23.4 pandas==1.5.1 seaborn==0.12.1 matplotlib==3.6.0 empiricaldist==0.6.7 statsmodels==0.13.5 scikit-learn==1.1.2 pyjanitor==0.23.1 session-info statsmodels
# Out:
# Collecting palmerpenguins==0.1.4
#   Using cached palmerpenguins-0.1.4-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy==1.23.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.23.4)
# Collecting pandas==1.5.1
#   Using cached pandas-1.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
# Requirement already satisfied: seaborn==0.12.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: matplotlib==3.6.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (3.6.0)
# Requirement already satisfied: empiricaldist==0.6.7 in /usr/local/lib/python3.9/site-packages (0.6.7)
# Collecting statsmodels==0.13.5
#   Using cached statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
# Requirement already satisfied: scikit-learn==1.1.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (1.1.2)
# Collecting pyjanitor==0.23.1
#   Using cached pyjanitor-0.23.1-py3-none-any.whl (147 kB)
# Requirement already satisfied: session-info in /usr/local/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas==1.5.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas==1.5.1) (2022.5)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib==3.6.0) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib==3.6.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib==3.6.0) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib==3.6.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib==3.6.0) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib==3.6.0) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib==3.6.0) (3.0.9)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/site-packages (from statsmodels==0.13.5) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.13.5) (1.9.3)
# Requirement already satisfied: joblib>=1.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn==1.1.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn==1.1.2) (3.1.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.9/site-packages (from pyjanitor==0.23.1) (8.3.1)
# Collecting pandas-flavor (from pyjanitor==0.23.1)
#   Using cached pandas_flavor-0.5.0-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.9/site-packages (from pyjanitor==0.23.1) (0.6.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.9/site-packages (from session-info) (0.8.0)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels==0.13.5) (1.16.0)
# Collecting xarray (from pandas-flavor->pyjanitor==0.23.1)
#   Using cached xarray-2023.5.0-py3-none-any.whl (994 kB)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.9/site-packages (from pandas-flavor->pyjanitor==0.23.1) (0.2)
# Installing collected packages: pandas, xarray, statsmodels, palmerpenguins, pandas-flavor, pyjanitor
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Uninstalling pandas-1.2.5:
# ERROR: Could not install packages due to an OSError: [Errno 30] Read-only file system: 'RECORD'
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import empiricaldist
import janitor
import matplotlib.pyplot as plt
import numpy as np
import palmerpenguins
import pandas as pd
import scipy.stats
import seaborn as sns
import sklearn.metrics
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats as ss
import session_info

# %% [markdown]
# ## Establecer apariencia general de los gráficos

# %%
preprocess_penguins_df = pd.read_csv('https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv')

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %%
preprocess_penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %% [markdown]
# ## Cargar los datos

# %% [markdown]
# ### Utilizando el paquete `palmerpenguins`

# %% [markdown]
# #### Datos crudos

# %% [markdown]
# #### Datos previamente procesados

# %%
preprocess_penguins_df = palmerpenguins.load_penguins_raw()
preprocess_penguins_df
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 1     PAL0708              2        Adelie Penguin (Pygoscelis adeliae)
# 2     PAL0708              3        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 4     PAL0708              5        Adelie Penguin (Pygoscelis adeliae)
# ..        ...            ...                                        ...
# 339   PAL0910             64  Chinstrap penguin (Pygoscelis antarctica)
# 340   PAL0910             65  Chinstrap penguin (Pygoscelis antarctica)
# 341   PAL0910             66  Chinstrap penguin (Pygoscelis antarctica)
# 342   PAL0910             67  Chinstrap penguin (Pygoscelis antarctica)
# 343   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# 0    Anvers  Torgersen  Adult, 1 Egg Stage          N1A1               Yes
# 1    Anvers  Torgersen  Adult, 1 Egg Stage          N1A2               Yes
# 2    Anvers  Torgersen  Adult, 1 Egg Stage          N2A1               Yes
# 3    Anvers  Torgersen  Adult, 1 Egg Stage          N2A2               Yes
# 4    Anvers  Torgersen  Adult, 1 Egg Stage          N3A1               Yes
# ..      ...        ...                 ...           ...               ...
# 339  Anvers      Dream  Adult, 1 Egg Stage         N98A2               Yes
# 340  Anvers      Dream  Adult, 1 Egg Stage         N99A1                No
# 341  Anvers      Dream  Adult, 1 Egg Stage         N99A2                No
# 342  Anvers      Dream  Adult, 1 Egg Stage        N100A1               Yes
# 343  Anvers      Dream  Adult, 1 Egg Stage        N100A2               Yes
#
#        Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0    2007-11-11                39.1               18.7                181.0
# 1    2007-11-11                39.5               17.4                186.0
# 2    2007-11-16                40.3               18.0                195.0
# 3    2007-11-16                 NaN                NaN                  NaN
# 4    2007-11-16                36.7               19.3                193.0
# ..          ...                 ...                ...                  ...
# 339  2009-11-19                55.8               19.8                207.0
# 340  2009-11-21                43.5               18.1                202.0
# 341  2009-11-21                49.6               18.2                193.0
# 342  2009-11-21                50.8               19.0                210.0
# 343  2009-11-21                50.2               18.7                198.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0           3750.0    MALE                NaN                NaN
# 1           3800.0  FEMALE            8.94956          -24.69454
# 2           3250.0  FEMALE            8.36821          -25.33302
# 3              NaN     NaN                NaN                NaN
# 4           3450.0  FEMALE            8.76651          -25.32426
# ..             ...     ...                ...                ...
# 339         4000.0    MALE            9.70465          -24.53494
# 340         3400.0  FEMALE            9.37608          -24.40753
# 341         3775.0    MALE            9.46180          -24.70615
# 342         4100.0    MALE            9.98044          -24.68741
# 343         3775.0  FEMALE            9.39305          -24.25255
#
#                                   Comments
# 0           Not enough blood for isotopes.
# 1                                      NaN
# 2                                      NaN
# 3                       Adult not sampled.
# 4                                      NaN
# ..                                     ...
# 339                                    NaN
# 340  Nest never observed with full clutch.
# 341  Nest never observed with full clutch.
# 342                                    NaN
# 343                                    NaN
#
# [344 rows x 17 columns]

# %% [markdown]
# ### Utilizando los conjuntos de datos de `seaborn`

# %%
sns.load_dataset("penguins")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# ### Utilizando la interfaz de `Deepnote`
#
# Links de importación de datos:
#
# - [Conjunto de datos crudos](https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins_raw.csv).
# - [Conjunto de datos previamente procesados](https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv).

# %%
pd.read_csv("penguins.csv")
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 3            NaN     NaN  2007
# 4         3450.0  female  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [344 rows x 8 columns]

# %% [markdown]
# # Colecta y validación de datos

# %% [markdown]
# ## ¿Qué tipo de dato son las variables del conjunto de datos?

# %%
preprocess_penguins_df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %% [markdown]
# ## ¿Cuántas variables de cada tipo de dato tenemos en el conjunto de datos?

# %%
(preprocess_penguins_df
.dtypes
.value_counts()
)
# Out:
# float64    4
# object     3
# int64      1
# dtype: int64

# %% [markdown]
# ## ¿Cuántas variables y observaciones tenemos en el conjunto de datos?

# %%
preprocess_penguins_df.shape
# Out:
# (344, 8)

# %% [markdown]
# ## ¿Existen valores nulos explícitos en el conjunto de datos?

# %%
(
    preprocess_penguins_df
    .isna()
    .any()
)
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# year                 False
# dtype: bool

# %% [markdown]
# ## De tener observaciones con valores nulos, ¿cuántas tenemos por cada variable?

# %%
(
    preprocess_penguins_df
    .isnull()
    .sum()
)
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# ## ¿Cuántos valores nulos tenemos en total en el conjunto de datos?

# %%
(
    preprocess_penguins_df
    .isnull()
    .sum()
    .sum()
)
# Out:
# 19

# %% [markdown]
# ## ¿Cuál es la proporción de valores nulos por cada variable?

# %%
(
    preprocess_penguins_df
    .isnull()
    .melt()
    .pipe( 
        lambda df: (
            sns.displot(
                data = df,
                y = "variable",
                hue = "value",
                multiple = "fill", 
                aspect = 2
            )
        )
        
    )
)

# %% [markdown]
# ## ¿Cómo podemos visualizar los valores nulos en todo el conjunto de datos?

# %%
(
    preprocess_penguins_df
    .isnull()
    .transpose()
    .pipe(
        lambda df:(
            sns.heatmap(
                data=df
            )
        )
    )
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## ¿Cuántas observaciones perdemos si eliminamos los datos faltantes?

# %%
processed_penguins_df = (
    preprocess_penguins_df
    .dropna()
)
processed_penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 4         3450.0  female  2007
# 5         3650.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [333 rows x 8 columns]

# %% [markdown]
# # Conteos y proporciones

# %% [markdown]
# ## Preludio: ¿Qué estadísticos describen el conjunto de datos?

# %% [markdown]
# ### Todas las variables

# %%
processed_penguins_df.describe(include ="all")
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      333     333      333.000000     333.000000         333.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       146     163             NaN            NaN                NaN
# mean       NaN     NaN       43.992793      17.164865         200.966967
# std        NaN     NaN        5.468668       1.969235          14.015765
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.500000      15.600000         190.000000
# 50%        NaN     NaN       44.500000      17.300000         197.000000
# 75%        NaN     NaN       48.600000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex         year
# count    333.000000   333   333.000000
# unique          NaN     2          NaN
# top             NaN  male          NaN
# freq            NaN   168          NaN
# mean    4207.057057   NaN  2008.042042
# std      805.215802   NaN     0.812944
# min     2700.000000   NaN  2007.000000
# 25%     3550.000000   NaN  2007.000000
# 50%     4050.000000   NaN  2008.000000
# 75%     4775.000000   NaN  2009.000000
# max     6300.000000   NaN  2009.000000

# %% [markdown]
# ### Solo las numéricas

# %%
processed_penguins_df.describe(include=[np.number])
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# ### Solo categóricas - 1

# %%
processed_penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# ### Solo categóricas - 2

# %%
(processed_penguins_df
.astype({
    'species':'category',
    'island':'category',
    'sex':'category'
})
.describe(include='category')
)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# ## ¿Cómo visualizar los conteos?

# %% [markdown]
# ### Pandas

# %%
(processed_penguins_df
.species
.value_counts()
.plot(
    kind="bar"
    )
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Seaborn

# %%
sns.catplot(
    data=processed_penguins_df,
    x="species",
    kind="count",
    palette=penguin_color
)

# %%
(
    processed_penguins_df
    .value_counts("species", sort=True)
    .reset_index(name="count")
    .pipe(
        lambda df: (
            sns.barplot(
                data=df,
                x="species",
                y="count",
                palette=penguin_color
            )
        )
    )
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='count'>

# %% [markdown]
# ### ¿Cómo visualizar las proporciones?

# %%
(
    processed_penguins_df
    .add_column("x", " ")
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x="x",
                hue="species",
                multiple="fill",
                palette=penguin_color
            )
        )
    )
)

# %% [markdown]
# # Medidas de tendencia central

# %% [markdown]
# ## Media o promedio

# %%
processed_penguins_df.bill_depth_mm.mean()
# Out:
# 17.164864864864867

# %%
np.mean(processed_penguins_df.bill_depth_mm)
# Out:
# 17.164864864864867

# %%
processed_penguins_df.mean()
# Out:
# /tmp/ipykernel_117/1618060137.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean()
# bill_length_mm         43.992793
# bill_depth_mm          17.164865
# flipper_length_mm     200.966967
# body_mass_g          4207.057057
# year                 2008.042042
# dtype: float64

# %% [markdown]
# ## Mediana

# %%
processed_penguins_df.median()
# Out:
# /tmp/ipykernel_117/3242987746.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.median()
# bill_length_mm         44.5
# bill_depth_mm          17.3
# flipper_length_mm     197.0
# body_mass_g          4050.0
# year                 2008.0
# dtype: float64

# %% [markdown]
# ## Moda

# %%
processed_penguins_df.mode()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe            41.1           17.0              190.0
#
#    body_mass_g   sex  year
# 0       3800.0  male  2009

# %%
processed_penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  male
# freq       146     163   168

# %% [markdown]
# # Medidas de dispersión

# %% [markdown]
# ## ¿Cuál es el valor máximo de las variables?

# %%
processed_penguins_df.max(numeric_only=True)
# Out:
# bill_length_mm         59.6
# bill_depth_mm          21.5
# flipper_length_mm     231.0
# body_mass_g          6300.0
# year                 2009.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el valor mínimo de las variables?

# %%
processed_penguins_df.min(numeric_only=True)
# Out:
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# year                 2007.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el rango de las variables?

# %%
processed_penguins_df.max(numeric_only=True)-processed_penguins_df.min(numeric_only=True)
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# year                    2.0
# dtype: float64

# %% [markdown]
# ## ¿Cuál es la desviación estándar de las variables?

# %%
processed_penguins_df.std()
# Out:
# /tmp/ipykernel_117/4261057176.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.std()
# bill_length_mm         5.468668
# bill_depth_mm          1.969235
# flipper_length_mm     14.015765
# body_mass_g          805.215802
# year                   0.812944
# dtype: float64

# %%
processed_penguins_df.mean() + processed_penguins_df.std()
# Out:
# /tmp/ipykernel_117/1334777921.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean() + processed_penguins_df.std()
# /tmp/ipykernel_117/1334777921.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean() + processed_penguins_df.std()
# bill_length_mm         49.461461
# bill_depth_mm          19.134100
# flipper_length_mm     214.982732
# body_mass_g          5012.272859
# year                 2008.854986
# dtype: float64

# %%
processed_penguins_df.mean() - processed_penguins_df.std()
# Out:
# /tmp/ipykernel_117/1336703272.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean() - processed_penguins_df.std()
# /tmp/ipykernel_117/1336703272.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.mean() - processed_penguins_df.std()
# bill_length_mm         38.524124
# bill_depth_mm          15.195629
# flipper_length_mm     186.951202
# body_mass_g          3401.841255
# year                 2007.229098
# dtype: float64

# %% [markdown]
# ## ¿Cuál es el rango intercuartílico?

# %%
processed_penguins_df.quantile(0.75)
# Out:
# /tmp/ipykernel_117/3609120765.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.75)
# bill_length_mm         48.6
# bill_depth_mm          18.7
# flipper_length_mm     213.0
# body_mass_g          4775.0
# year                 2009.0
# Name: 0.75, dtype: float64

# %%
processed_penguins_df.quantile(0.25)
# Out:
# /tmp/ipykernel_117/2653252021.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.25)
# bill_length_mm         39.5
# bill_depth_mm          15.6
# flipper_length_mm     190.0
# body_mass_g          3550.0
# year                 2007.0
# Name: 0.25, dtype: float64

# %%
processed_penguins_df.quantile(0.75)-processed_penguins_df.quantile(0.25)
# Out:
# /tmp/ipykernel_117/1736177706.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.quantile(0.75)-processed_penguins_df.quantile(0.25)
# bill_length_mm          9.1
# bill_depth_mm           3.1
# flipper_length_mm      23.0
# body_mass_g          1225.0
# year                    2.0
# dtype: float64

# %%
(
    processed_penguins_df
    .quantile(q=[0.75, 0.50, 0.25])
    .transpose()
    .rename_axis("variable")
    .reset_index()
    .assign(
        iqr= lambda df:df[0.75] -df[0.25]
    )
)
# Out:
# /tmp/ipykernel_117/1817335574.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df
#             variable    0.75     0.5    0.25     iqr
# 0     bill_length_mm    48.6    44.5    39.5     9.1
# 1      bill_depth_mm    18.7    17.3    15.6     3.1
# 2  flipper_length_mm   213.0   197.0   190.0    23.0
# 3        body_mass_g  4775.0  4050.0  3550.0  1225.0
# 4               year  2009.0  2008.0  2007.0     2.0

# %% [markdown]
# ## ¿Cómo puedo visualizar la distribución de una variable?

# %% [markdown]
# ### Histograma

# %%
sns.histplot(
    data=processed_penguins_df,
    x= "flipper_length_mm"
)
plt.axvline(
    x=processed_penguins_df.flipper_length_mm.mean(),
    color= "red",
    linestyle="dashed",
    linewidth=2
)

# %% [markdown]
# ### Diagrama de caja / boxplot

# %%
sns.boxplot(
    data=processed_penguins_df,
    x="flipper_length_mm"
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm'>

# %% [markdown]
# ### Limitaciones

# %%
def freedman_diaconis_bindwidth(x: pd.Series) -> float:
    """Find optimal bindwidth using Freedman-Diaconis rule."""

    IQR = x.quantile(0.75) - x.quantile(0.25)
    N = x.size

    return 2 * IQR / N ** (1 / 3)

# %%
sns.histplot(
    data=processed_penguins_df,
    x= "flipper_length_mm",
    binwidth=10
)
plt.axvline(
    x=processed_penguins_df.flipper_length_mm.mean(),
    color= "red",
    linestyle="dashed",
    linewidth=2
)

# %% [markdown]
# # Distribuciones: PMFs, CDFs y PDFs

# %% [markdown]
# ## Funciones de probabilidad de masas (PMFs)

# %% [markdown]
# ### Utilizando `seaborn`

# %%
sns.histplot(
    data=processed_penguins_df,
    x="flipper_length_mm",
    binwidth=1,
    stat="probability"
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Probability'>

# %% [markdown]
# ### Utilizando `empiricaldist`

# %%
pmf_flipper_length_mm = empiricaldist.Pmf.from_seq(
    processed_penguins_df.flipper_length_mm,
    normalize=True
)

# %%
pmf_flipper_length_mm.bar()

# %%
pmf_flipper_length_mm(190)
# Out:
# 0.06306306306306306

# %%
processed_penguins_df.flipper_length_mm.max()
# Out:
# 231.0

# %% [markdown]
# ## Funciones empirícas de probabilidad acumulada (ECDFs)

# %% [markdown]
# ### Utilizando `seaborn`

# %%
sns.ecdfplot(
    data=processed_penguins_df,
    x="flipper_length_mm"
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# ### Utilizando `empiricaldist`

# %%
cdf_flipper_length_mm = empiricaldist.Cdf.from_seq(
    processed_penguins_df.flipper_length_mm,
    normalize=True
)

# %%
cdf_flipper_length_mm.plot()

q = 200
p=cdf_flipper_length_mm.forward(q)

plt.vlines(
    x=q,
    ymin=0,
    ymax=p,
    color="black",
    linestyles="dashed"
)

plt.hlines(
    y=p,
    xmin=pmf_flipper_length_mm.qs[0],
    xmax=q,
    color="black",
    linestyles="dashed"
)

plt.plot(q, p, "ro")

# %%
cdf_flipper_length_mm.step ( )
p_1 = 8.25 # Specify probability
P_2 = 8.75
ps = ( 0.25 , 0.75 ) # IQR
qs = cdf_flipper_length_mm.inverse(ps)
plt.vlines (
    x = qs,
    ymin = 0,
    ymax=ps,
    color='black',
    linestyle='dashed'
)

plt.hlines(
   y=ps,
   xmin=pmf_flipper_length_mm.qs[0],
   xmax=qs,
   color='black',
   linestyle='dashed'
)

plt.scatter(
   x=qs,
   y=ps,
   color='red',
   zorder=2
)

# %% [markdown]
# ### Comparando distribuciones

# %%
sns.ecdfplot(
    data=processed_penguins_df,
    x="flipper_length_mm",
    hue="species",
    palette=penguin_color

)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# ## Funciones de densidad de probabilidad

# %%
sns.kdeplot(
    data= processed_penguins_df,
    x="flipper_length_mm",
    bw_method=0.1
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Density'>

# %%
stats = processed_penguins_df.body_mass_g.describe()
stats
# Out:
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
xs = np.linspace(stats["min"], stats["max"])
ys = scipy.stats.norm(stats["mean"], stats["std"]).cdf(xs)

plt.plot(xs, ys, color = "black", linestyle="dashed")

empiricaldist.Cdf.from_seq(
    processed_penguins_df.body_mass_g,
    normalize=True
).plot()
# Out:
# <AxesSubplot: >

# %%
xs = np.linspace(stats["min"], stats["max"])
ys = scipy.stats.norm(stats["mean"], stats["std"]).pdf(xs)

plt.plot(xs, ys, color = "black", linestyle="dashed")

sns.kdeplot(
    data=processed_penguins_df,
    x= "body_mass_g"
)
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# # Ley de los Grandes Números y Teorema del Límite Central

# %% [markdown]
# ## Ley de los Grandes Números

# %%
dice = empiricaldist.Pmf.from_seq([1, 2, 3, 4, 5, 6])
dice.bar()

# %%
for sample_size in (1e2, 1e3, 1e4):
    sample_size = int(sample_size)
    values = dice.sample(sample_size)
    sample_pmf = empiricaldist.Pmf.from_seq(values)

    plt.figure(figsize=(5, 5))
    sample_pmf.bar()
    plt.axhline(y=1/6, color ="red", linestyle="dashed")
    plt.ylim([0, 0.50])
    plt.title(f"Sample size: {sample_size}")

# %% [markdown]
# ## Teorema del Límite Central

# %%
processed_penguins_df.sex.value_counts(normalize=True)
# Out:
# male      0.504505
# female    0.495495
# Name: sex, dtype: float64

# %%
sex_numeric = processed_penguins_df.sex.replace(["male","female"],[1, 0])
sex_numeric
# Out:
# 0      1
# 1      0
# 2      0
# 4      0
# 5      1
#       ..
# 339    1
# 340    0
# 341    1
# 342    1
# 343    0
# Name: sex, Length: 333, dtype: int64

# %%
number_samples = 1000
sample_size = 35

samples_df = pd.DataFrame()

np.random.seed(42)
for i in range(1, number_samples + 1):
    sex_numeric_sample = sex_numeric.sample(sample_size, replace=True).to_numpy()
    sample_name = f"sample_{i}"
    samples_df[sample_name] = sex_numeric_sample


male_population_mean = samples_df.mean().mean()
print(f"Estimated percentage of male penguins in population is: {male_population_mean * 100:.4f}%")
# Out:
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample
# /tmp/ipykernel_117/2100621360.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   samples_df[sample_name] = sex_numeric_sample

# %%
sample_means_binomial = pd.DataFrame(samples_df.mean(), columns=['sample_mean'])
sns.kdeplot(data=sample_means_binomial)
plt.axvline(x=sex_numeric.mean(), color='red', linestyle='dashed')

# %%
sample_size_experiment = pd.DataFrame(
    [[i, samples_df.iloc[:, 0:i].mean().mean().mean()] for i in range(1, number_samples + 1)],
    columns=['sample_size', 'estimated_mean']
)

# %%
sns.scatterplot(
    data=sample_size_experiment,
    x='sample_size',
    y='estimated_mean'
)

plt.axhline(
    y=sex_numeric.mean(),
    color='red',
    linestyle='dashed'
)

plt.ylim([sex_numeric.mean() - 0.20, sex_numeric.mean() + 0.20])
# Out:
# (0.30450450450450445, 0.7045045045045044)

# %% [markdown]
# # Estableciendo relaciones: Gráfica de puntos

# %%
sns.scatterplot(
    data = processed_penguins_df,
    x="bill_length_mm",
    y="bill_depth_mm",
    alpha=1/2,
    s=100
)
# Out:
# <AxesSubplot: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.displot(
    data=processed_penguins_df,
    x="bill_length_mm",
    y="bill_depth_mm",
    rug=True
)

# %%
sns.displot(
    data=processed_penguins_df,
    x="bill_length_mm",
    y="bill_depth_mm",
    rug=True,
    kind="kde"
)

# %%
sns.jointplot(
    data=processed_penguins_df,
    x="bill_length_mm",
    y="bill_depth_mm"
)

# %% [markdown]
# # Estableciendo relaciones: Gráficos de violín y boxplots

# %%
sns.scatterplot(
    data=processed_penguins_df,
    x="species",
    y="flipper_length_mm",
    hue="species",
    palette=penguin_color
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.stripplot(
    data=processed_penguins_df,
    x="species",
    y="flipper_length_mm",
    palette=penguin_color

)
# Out:
# /tmp/ipykernel_117/46935050.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.boxplot(
    data=processed_penguins_df,
    x="flipper_length_mm",
    y="species",
    palette=penguin_color,
)
ax= sns.stripplot(
    data=processed_penguins_df,
    x="flipper_length_mm",
    y="species",
    color=".3"
)

# %%
ax= sns.violinplot(
    data=processed_penguins_df,
    y="flipper_length_mm",
    x="species",
    color=".9"
)

ax=sns.stripplot(
    data=processed_penguins_df,
    x="species",
    y="flipper_length_mm",
    palette=penguin_color
)
# Out:
# /tmp/ipykernel_117/3098150854.py:8: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   ax=sns.stripplot(

# %%
sns.swarmplot(
    data=processed_penguins_df,
    x="species",
    y="flipper_length_mm",
    hue="species",
    palette=penguin_color
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# # Estableciendo relaciones: Matrices de correlación

# %% [markdown]
# ## ¿Existe una correlación lineal entre alguna de nuestras variables?

# %%
processed_penguins_df.corr()
# Out:
# /tmp/ipykernel_117/4090656914.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   processed_penguins_df.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
# year                     0.032657      -0.048182           0.151068
#
#                    body_mass_g      year
# bill_length_mm        0.589451  0.032657
# bill_depth_mm        -0.472016 -0.048182
# flipper_length_mm     0.872979  0.151068
# body_mass_g           1.000000  0.021862
# year                  0.021862  1.000000

# %% [markdown]
# ## ¿Cómo puedo visualizar los coeficientes de correlación?

# %%
sns.heatmap(
    data=processed_penguins_df.corr(),
    cmap=sns.diverging_palette(20, 230, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
)
# Out:
# /tmp/ipykernel_117/4127411638.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins_df.corr(),
# <AxesSubplot: >

# %%
sns.clustermap(
    data=processed_penguins_df.corr(),
    cmap=sns.diverging_palette(20, 230, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    annot=True
)
# Out:
# /tmp/ipykernel_117/3065477016.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data=processed_penguins_df.corr(),

# %% [markdown]
# ## ¿Cómo podría representar una variable categórica como númerica discreta?

# %% [markdown]
# ## ¿Cuál es una limitante de los coeficientes de correlación lineal?

# %% [markdown]
# ### Solo nos ayuda a determinar la posible existencia de una correlación lineal; sin embargo, su ausenecia no significa que no exista otro tipo de correlación

# %% [markdown]
# ### El coeficiente de correlación no nos habla del impacto de la relación

# %% [markdown]
# # Estableciendo relaciones: Análisis de regresión simple

# %% [markdown]
# # Limitaciones del análisis de regresión simple

# %% [markdown]
# ## La regresión lineal simple no es simétrica

# %% [markdown]
# ## La regresión no nos dice nada sobre la causalidad, pero existen herramientas para separar las relaciones entre múltiples variables

# %% [markdown]
# # Análisis de regresión múltiple

# %% [markdown]
# ## Olvidé mi báscula para pesar a los pingüinos, ¿cuál sería la mejor forma de capturar ese dato?

# %% [markdown]
# ### Creando modelos

# %% [markdown]
# #### Modelo 1

# %% [markdown]
# #### Modelo 2

# %% [markdown]
# #### Modelo 3

# %% [markdown]
# #### Modelo 4

# %% [markdown]
# #### Modelo 5

# %% [markdown]
# ### Visualizando resultados

# %% [markdown]
# #### Creación de tabla de resultados

# %% [markdown]
# #### ECDFs

# %% [markdown]
# #### PDFs

# %% [markdown]
# #### ¿Qué pudimos haber encontrado antes de hacer los modelos?

# %% [markdown]
# # Análisis de regresión logística

# %% [markdown]
# ## ¿Podemos crear un modelo que nos ayude a definir si un pingüino es macho o hembra?

# %% [markdown]
# ## Exploración de nuestras variables categóricas

# %% [markdown]
# ## ¿Podemos definir un modelo que nos ayude a identificar si un pingüino pertenece a determinada clase?

# %% [markdown]
# # Paradoja de Simpson

# %% [markdown]
# ## Información de sesión

# %%
session_info.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=345e09e4-cd1b-4bf0-97e6-f59bd22fe9c4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
