# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2,figsize=(5,5))
axes[0].plot(x,y,label="$sin(x)$")
axes[0].set_title('Relacion X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend()
axes[1].plot(y,x)
axes[1].set_title('Relacion Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
fig.tight_layout()

# %%
plt.plot(x,y,label='sin(x)')
plt.title('Este es un titulo')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
fig.tight_layout()

# %% [markdown]
# ### Cómo dar contexto a los gráficos
# #### Creamos nuestras gráficas comunes

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b')
ax2.plot(y,x, 'r')
plt.show()
fig.tight_layout()

# %% [markdown]
# ### Contexto a los gráficos con títulos
# #### Para crear los títulos realiza lo siguiente:

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b')
ax1.set_title("Relacion X - Y")

ax2.plot(y,x, 'r')
ax2.set_title("Relacion Y - X")
fig.tight_layout()

# %% [markdown]
# ### Contexto agregando etiquetas
# #### Agrega labels en los ejes

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b', )
ax1.set_title("Relacion X - Y")
ax1.set_xlabel("X")
ax1.set_ylabel("Y")

ax2.plot(y,x, 'r')
ax2.set_title("Relacion Y - X")
ax2.set_xlabel("Y")
ax2.set_ylabel("X")
fig.tight_layout()

# %% [markdown]
# ### Cambiar el tamaño a las figuras
# #### Realiza la siguiente acción:

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize= (1,10))
fig.tight_layout()
# Out:
# C:\Users\celio\AppData\Local\Temp\ipykernel_14752\1621883756.py:2: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %% [markdown]
# ### * Aplicar etiquetas (por defecto pone la mejor opción)

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
ax1.plot(x,y, 'b', label = "sin(x)")
ax1.set_title("Relacion X - Y")
ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.legend()

# %% [markdown]
# ### * Modificar la localización de la etiqueta

# %%
ax1.legend(loc = "upper center")

# %% [markdown]
# #### Otras ubicaciones
# #### upper right; upper left; lower left; lower right; right
