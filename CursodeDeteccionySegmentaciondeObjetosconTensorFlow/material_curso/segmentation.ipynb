# %% [markdown]
# # Proyecto de segmentación: conducción autónoma

# %% [markdown]
# # 1. Lectura y visualización de un dataset de segmentation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/Platzi/dataset_segmentation/camseq.zip'
# Out:
# Archive:  /content/drive/MyDrive/Platzi/dataset_segmentation/camseq.zip
# replace 0016E5_07959.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf

from sklearn.model_selection import train_test_split

# %%
dataset_path = './'
filenames = os.listdir(dataset_path)
filenames.sort()


image_list = []
masks_list = []

for filename in filenames:
  if len(filename.split('.')) > 1 and filename.split('.')[1][:3] == 'png':
    if filename.split('.')[0][-2:] == '_L':
      masks_list.append(dataset_path + '/' + filename)
    else:
      image_list.append(dataset_path + '/' + filename)

# %%
train_input_img_paths, val_input_img_paths, train_target_mask_paths, val_target_mask_paths = train_test_split(image_list, masks_list, test_size=0.2, random_state=42)

# %%
def load_data(images_path, masks_path):
  samples = {'images': [], 'masks': []}

  for i in range(len(images_path)):
    img = plt.imread(images_path[i])
    mask = plt.imread(masks_path[i])
    img = cv2.resize(img, (256, 256))
    masks = cv2.resize(mask, (256, 256))

    samples['images'].append(img)
    samples['masks'].append(masks)

  samples = {
      'images': np.array(samples['images']),
      'masks': np.array(samples['masks']),
  }

  return samples

# %%
train_samples = load_data(train_input_img_paths, train_target_mask_paths)
test_samples = load_data(val_input_img_paths, val_target_mask_paths)

# %%
plt.figure(figsize=(20, 20))
plt.subplot(1, 2, 1)
plt.imshow(train_samples['images'][10])
plt.subplot(1, 2, 2)
plt.imshow(train_samples['masks'][10])
plt.show()

# %% [markdown]
# # 2. Creando una red U-Net para segmentación.

# %%
def create_conv_block(input_tensor, num_filters):
  x = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=(3, 3), kernel_initializer='he_normal', padding='same')(input_tensor)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Activation('relu')(x)

  x = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=(3, 3), kernel_initializer='he_normal', padding='same')(x)
  x = tf.keras.layers.BatchNormalization()(x)
  x = tf.keras.layers.Activation('relu')(x)

  return x

# %%
def create_unet(input_shape, num_filters=16, dropout=0.1):
  # Encoder
  c1 = create_conv_block(input_shape, num_filters * 1)
  p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)
  p1 = tf.keras.layers.Dropout(dropout)(p1)

  c2 = create_conv_block(p1, num_filters * 2)
  p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)
  p2 = tf.keras.layers.Dropout(dropout)(p2)

  c3 = create_conv_block(p2, num_filters * 4)
  p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)
  p3 = tf.keras.layers.Dropout(dropout)(p3)

  c4 = create_conv_block(p3, num_filters * 8)
  p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)
  p4 = tf.keras.layers.Dropout(dropout)(p4)

  c5 = create_conv_block(p4, num_filters * 16)

  # Decoder
  u6 = tf.keras.layers.Convolution2DTranspose(num_filters*8, (3, 3), strides=(2, 2), padding='same')(c5)
  u6 = tf.keras.layers.concatenate([u6, c4])
  u6 = tf.keras.layers.Dropout(dropout)(u6)
  c6 = create_conv_block(u6, num_filters*8)


  u7 = tf.keras.layers.Convolution2DTranspose(num_filters*4, (3, 3), strides=(2, 2), padding='same')(c6)
  u7 = tf.keras.layers.concatenate([u7, c3])
  u7 = tf.keras.layers.Dropout(dropout)(u7)
  c7 = create_conv_block(u7, num_filters*4)

  u8 = tf.keras.layers.Convolution2DTranspose(num_filters*2, (3, 3), strides=(2, 2), padding='same')(c7)
  u8 = tf.keras.layers.concatenate([u8, c2])
  u8 = tf.keras.layers.Dropout(dropout)(u8)
  c8 = create_conv_block(u8, num_filters*2)

  u9 = tf.keras.layers.Convolution2DTranspose(num_filters*1, (3, 3), strides=(2, 2), padding='same')(c8)
  u9 = tf.keras.layers.concatenate([u9, c1])
  u9 = tf.keras.layers.Dropout(dropout)(u9)
  c9 = create_conv_block(u9, num_filters*1)


  output = tf.keras.layers.Conv2D(3, (1, 1), activation='sigmoid')(c9)
  model = tf.keras.Model(inputs = [input_shape], outputs = [output])

  return model

# %%
inputs = tf.keras.layers.Input((256, 256, 3))
model = create_unet(inputs)

# %%
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model_history = model.fit(train_samples['images'], train_samples['masks'], epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 22s 2s/step - loss: 0.7660 - accuracy: 0.3744
# Epoch 2/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.7129 - accuracy: 0.3879
# Epoch 3/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.6860 - accuracy: 0.4136
# Epoch 4/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.6662 - accuracy: 0.4521
# Epoch 5/200
# 3/3 [==============================] - 1s 282ms/step - loss: 0.6493 - accuracy: 0.5008
# Epoch 6/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.6350 - accuracy: 0.5261
# Epoch 7/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.6218 - accuracy: 0.5275
# Epoch 8/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.6108 - accuracy: 0.5142
# Epoch 9/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.6007 - accuracy: 0.5038
# Epoch 10/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.5926 - accuracy: 0.4965
# Epoch 11/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5848 - accuracy: 0.5037
# Epoch 12/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.5777 - accuracy: 0.5164
# Epoch 13/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5708 - accuracy: 0.5284
# Epoch 14/200
# 3/3 [==============================] - 1s 281ms/step - loss: 0.5645 - accuracy: 0.5403
# Epoch 15/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.5585 - accuracy: 0.5527
# Epoch 16/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5530 - accuracy: 0.5659
# Epoch 17/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.5484 - accuracy: 0.5768
# Epoch 18/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.5439 - accuracy: 0.5893
# Epoch 19/200
# 3/3 [==============================] - 1s 284ms/step - loss: 0.5399 - accuracy: 0.5965
# Epoch 20/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5362 - accuracy: 0.6032
# Epoch 21/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.5329 - accuracy: 0.6027
# Epoch 22/200
# 3/3 [==============================] - 1s 285ms/step - loss: 0.5299 - accuracy: 0.6063
# Epoch 23/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.5269 - accuracy: 0.6080
# Epoch 24/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5247 - accuracy: 0.6067
# Epoch 25/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.5223 - accuracy: 0.6051
# Epoch 26/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5203 - accuracy: 0.6055
# Epoch 27/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.5181 - accuracy: 0.6058
# Epoch 28/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5163 - accuracy: 0.6061
# Epoch 29/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.5145 - accuracy: 0.6076
# Epoch 30/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.5129 - accuracy: 0.6087
# Epoch 31/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.5113 - accuracy: 0.6095
# Epoch 32/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.5098 - accuracy: 0.6060
# Epoch 33/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.5085 - accuracy: 0.6089
# Epoch 34/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.5072 - accuracy: 0.6064
# Epoch 35/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.5059 - accuracy: 0.6064
# Epoch 36/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.5046 - accuracy: 0.6058
# Epoch 37/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.5037 - accuracy: 0.6053
# Epoch 38/200
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5024 - accuracy: 0.6063
# Epoch 39/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.5013 - accuracy: 0.6032
# Epoch 40/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.5004 - accuracy: 0.6025
# Epoch 41/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.4995 - accuracy: 0.6055
# Epoch 42/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.4985 - accuracy: 0.6015
# Epoch 43/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.4976 - accuracy: 0.6000
# Epoch 44/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.4967 - accuracy: 0.6014
# Epoch 45/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.4961 - accuracy: 0.5963
# Epoch 46/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4953 - accuracy: 0.6003
# Epoch 47/200
# 3/3 [==============================] - 1s 287ms/step - loss: 0.4946 - accuracy: 0.5969
# Epoch 48/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4939 - accuracy: 0.5945
# Epoch 49/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.4931 - accuracy: 0.5977
# Epoch 50/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.4925 - accuracy: 0.5939
# Epoch 51/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.4920 - accuracy: 0.5972
# Epoch 52/200
# 3/3 [==============================] - 1s 288ms/step - loss: 0.4912 - accuracy: 0.6032
# Epoch 53/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.4905 - accuracy: 0.5949
# Epoch 54/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.4901 - accuracy: 0.5995
# Epoch 55/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4900 - accuracy: 0.6111
# Epoch 56/200
# 3/3 [==============================] - 1s 289ms/step - loss: 0.4897 - accuracy: 0.6076
# Epoch 57/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4890 - accuracy: 0.6010
# Epoch 58/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.4886 - accuracy: 0.6181
# Epoch 59/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4880 - accuracy: 0.6016
# Epoch 60/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.4873 - accuracy: 0.6121
# Epoch 61/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.4868 - accuracy: 0.6130
# Epoch 62/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.4864 - accuracy: 0.6109
# Epoch 63/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.4860 - accuracy: 0.6164
# Epoch 64/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4855 - accuracy: 0.6092
# Epoch 65/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.4853 - accuracy: 0.6012
# Epoch 66/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.4848 - accuracy: 0.6186
# Epoch 67/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4845 - accuracy: 0.6138
# Epoch 68/200
# 3/3 [==============================] - 1s 290ms/step - loss: 0.4844 - accuracy: 0.6049
# Epoch 69/200
# 3/3 [==============================] - 1s 310ms/step - loss: 0.4841 - accuracy: 0.6293
# Epoch 70/200
# 3/3 [==============================] - 1s 311ms/step - loss: 0.4839 - accuracy: 0.6135
# Epoch 71/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.4836 - accuracy: 0.6065
# Epoch 72/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4830 - accuracy: 0.6202
# Epoch 73/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4826 - accuracy: 0.6128
# Epoch 74/200
# 3/3 [==============================] - 1s 309ms/step - loss: 0.4821 - accuracy: 0.6219
# Epoch 75/200
# 3/3 [==============================] - 1s 311ms/step - loss: 0.4817 - accuracy: 0.6032
# Epoch 76/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4815 - accuracy: 0.6149
# Epoch 77/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4811 - accuracy: 0.6189
# Epoch 78/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4807 - accuracy: 0.6147
# Epoch 79/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4804 - accuracy: 0.6224
# Epoch 80/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4802 - accuracy: 0.6266
# Epoch 81/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.4799 - accuracy: 0.6207
# Epoch 82/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.4797 - accuracy: 0.6159
# Epoch 83/200
# 3/3 [==============================] - 1s 296ms/step - loss: 0.4793 - accuracy: 0.6264
# Epoch 84/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.4792 - accuracy: 0.6181
# Epoch 85/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4789 - accuracy: 0.6373
# Epoch 86/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4786 - accuracy: 0.6215
# Epoch 87/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4785 - accuracy: 0.6248
# Epoch 88/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.4783 - accuracy: 0.6275
# Epoch 89/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4780 - accuracy: 0.6262
# Epoch 90/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4778 - accuracy: 0.6422
# Epoch 91/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.4777 - accuracy: 0.6097
# Epoch 92/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4776 - accuracy: 0.6294
# Epoch 93/200
# 3/3 [==============================] - 1s 312ms/step - loss: 0.4772 - accuracy: 0.6521
# Epoch 94/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.4772 - accuracy: 0.6362
# Epoch 95/200
# 3/3 [==============================] - 1s 296ms/step - loss: 0.4770 - accuracy: 0.6307
# Epoch 96/200
# 3/3 [==============================] - 1s 291ms/step - loss: 0.4767 - accuracy: 0.6438
# Epoch 97/200
# 3/3 [==============================] - 1s 292ms/step - loss: 0.4764 - accuracy: 0.6347
# Epoch 98/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4762 - accuracy: 0.6437
# Epoch 99/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4761 - accuracy: 0.6415
# Epoch 100/200
# 3/3 [==============================] - 1s 293ms/step - loss: 0.4758 - accuracy: 0.6341
# Epoch 101/200
# 3/3 [==============================] - 1s 313ms/step - loss: 0.4757 - accuracy: 0.6455
# Epoch 102/200
# 3/3 [==============================] - 1s 314ms/step - loss: 0.4754 - accuracy: 0.6417
# Epoch 103/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4753 - accuracy: 0.6499
# Epoch 104/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4754 - accuracy: 0.6496
# Epoch 105/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4751 - accuracy: 0.6344
# Epoch 106/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4750 - accuracy: 0.6572
# Epoch 107/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4748 - accuracy: 0.6548
# Epoch 108/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4746 - accuracy: 0.6351
# Epoch 109/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4745 - accuracy: 0.6624
# Epoch 110/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4743 - accuracy: 0.6344
# Epoch 111/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4742 - accuracy: 0.6585
# Epoch 112/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4742 - accuracy: 0.6546
# Epoch 113/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4740 - accuracy: 0.6483
# Epoch 114/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.4741 - accuracy: 0.6424
# Epoch 115/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4741 - accuracy: 0.6715
# Epoch 116/200
# 3/3 [==============================] - 1s 294ms/step - loss: 0.4740 - accuracy: 0.6476
# Epoch 117/200
# 3/3 [==============================] - 1s 302ms/step - loss: 0.4739 - accuracy: 0.6496
# Epoch 118/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4738 - accuracy: 0.6586
# Epoch 119/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.4735 - accuracy: 0.6431
# Epoch 120/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4734 - accuracy: 0.6613
# Epoch 121/200
# 3/3 [==============================] - 1s 295ms/step - loss: 0.4732 - accuracy: 0.6439
# Epoch 122/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4730 - accuracy: 0.6762
# Epoch 123/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4729 - accuracy: 0.6551
# Epoch 124/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4729 - accuracy: 0.6258
# Epoch 125/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4727 - accuracy: 0.6929
# Epoch 126/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4727 - accuracy: 0.6299
# Epoch 127/200
# 3/3 [==============================] - 1s 302ms/step - loss: 0.4725 - accuracy: 0.6626
# Epoch 128/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4722 - accuracy: 0.6720
# Epoch 129/200
# 3/3 [==============================] - 1s 296ms/step - loss: 0.4721 - accuracy: 0.6317
# Epoch 130/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4720 - accuracy: 0.6697
# Epoch 131/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4718 - accuracy: 0.6515
# Epoch 132/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4717 - accuracy: 0.6647
# Epoch 133/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4716 - accuracy: 0.6506
# Epoch 134/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.4715 - accuracy: 0.6629
# Epoch 135/200
# 3/3 [==============================] - 1s 325ms/step - loss: 0.4713 - accuracy: 0.6556
# Epoch 136/200
# 3/3 [==============================] - 1s 313ms/step - loss: 0.4714 - accuracy: 0.6516
# Epoch 137/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4712 - accuracy: 0.6715
# Epoch 138/200
# 3/3 [==============================] - 1s 302ms/step - loss: 0.4711 - accuracy: 0.6747
# Epoch 139/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.4712 - accuracy: 0.6499
# Epoch 140/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.4709 - accuracy: 0.6736
# Epoch 141/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4708 - accuracy: 0.6592
# Epoch 142/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4709 - accuracy: 0.6727
# Epoch 143/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4705 - accuracy: 0.6657
# Epoch 144/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4705 - accuracy: 0.6636
# Epoch 145/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4705 - accuracy: 0.6713
# Epoch 146/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4706 - accuracy: 0.6470
# Epoch 147/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4705 - accuracy: 0.6845
# Epoch 148/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4703 - accuracy: 0.6558
# Epoch 149/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4703 - accuracy: 0.6724
# Epoch 150/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4702 - accuracy: 0.6722
# Epoch 151/200
# 3/3 [==============================] - 1s 302ms/step - loss: 0.4699 - accuracy: 0.6748
# Epoch 152/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4698 - accuracy: 0.6695
# Epoch 153/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4697 - accuracy: 0.6703
# Epoch 154/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4696 - accuracy: 0.6751
# Epoch 155/200
# 3/3 [==============================] - 1s 298ms/step - loss: 0.4696 - accuracy: 0.6894
# Epoch 156/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4696 - accuracy: 0.6719
# Epoch 157/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4695 - accuracy: 0.6763
# Epoch 158/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.4694 - accuracy: 0.6759
# Epoch 159/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4692 - accuracy: 0.6696
# Epoch 160/200
# 3/3 [==============================] - 1s 308ms/step - loss: 0.4693 - accuracy: 0.6828
# Epoch 161/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.4692 - accuracy: 0.6666
# Epoch 162/200
# 3/3 [==============================] - 1s 310ms/step - loss: 0.4690 - accuracy: 0.6896
# Epoch 163/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4690 - accuracy: 0.6831
# Epoch 164/200
# 3/3 [==============================] - 1s 302ms/step - loss: 0.4689 - accuracy: 0.6824
# Epoch 165/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4689 - accuracy: 0.6792
# Epoch 166/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.4686 - accuracy: 0.6877
# Epoch 167/200
# 3/3 [==============================] - 1s 310ms/step - loss: 0.4687 - accuracy: 0.6715
# Epoch 168/200
# 3/3 [==============================] - 1s 311ms/step - loss: 0.4685 - accuracy: 0.6865
# Epoch 169/200
# 3/3 [==============================] - 1s 332ms/step - loss: 0.4684 - accuracy: 0.6816
# Epoch 170/200
# 3/3 [==============================] - 1s 308ms/step - loss: 0.4684 - accuracy: 0.6644
# Epoch 171/200
# 3/3 [==============================] - 1s 302ms/step - loss: 0.4684 - accuracy: 0.6906
# Epoch 172/200
# 3/3 [==============================] - 1s 310ms/step - loss: 0.4682 - accuracy: 0.6918
# Epoch 173/200
# 3/3 [==============================] - 1s 309ms/step - loss: 0.4682 - accuracy: 0.6905
# Epoch 174/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4681 - accuracy: 0.6720
# Epoch 175/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4681 - accuracy: 0.6929
# Epoch 176/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.4680 - accuracy: 0.6920
# Epoch 177/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.4680 - accuracy: 0.6867
# Epoch 178/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4679 - accuracy: 0.6850
# Epoch 179/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4679 - accuracy: 0.6838
# Epoch 180/200
# 3/3 [==============================] - 1s 310ms/step - loss: 0.4679 - accuracy: 0.6956
# Epoch 181/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4678 - accuracy: 0.6893
# Epoch 182/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4677 - accuracy: 0.7027
# Epoch 183/200
# 3/3 [==============================] - 1s 300ms/step - loss: 0.4676 - accuracy: 0.6795
# Epoch 184/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4677 - accuracy: 0.6871
# Epoch 185/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4676 - accuracy: 0.6831
# Epoch 186/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.4676 - accuracy: 0.7056
# Epoch 187/200
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4677 - accuracy: 0.7155
# Epoch 188/200
# 3/3 [==============================] - 1s 299ms/step - loss: 0.4675 - accuracy: 0.7086
# Epoch 189/200
# 3/3 [==============================] - 1s 308ms/step - loss: 0.4674 - accuracy: 0.6757
# Epoch 190/200
# 3/3 [==============================] - 1s 303ms/step - loss: 0.4674 - accuracy: 0.7079
# Epoch 191/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4673 - accuracy: 0.6835
# Epoch 192/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4673 - accuracy: 0.7094
# Epoch 193/200
# 3/3 [==============================] - 1s 308ms/step - loss: 0.4672 - accuracy: 0.6919
# Epoch 194/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.4671 - accuracy: 0.7224
# Epoch 195/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4671 - accuracy: 0.7210
# Epoch 196/200
# 3/3 [==============================] - 1s 305ms/step - loss: 0.4671 - accuracy: 0.6915
# Epoch 197/200
# 3/3 [==============================] - 1s 304ms/step - loss: 0.4670 - accuracy: 0.7023
# Epoch 198/200
# 3/3 [==============================] - 1s 307ms/step - loss: 0.4669 - accuracy: 0.7207
# Epoch 199/200
# 3/3 [==============================] - 1s 306ms/step - loss: 0.4669 - accuracy: 0.7114
# Epoch 200/200
# 3/3 [==============================] - 1s 297ms/step - loss: 0.4667 - accuracy: 0.7052

# %%
plt.plot(model_history.history['loss'], label='training_loss')
plt.plot(model_history.history['accuracy'], label='training_accuracy')
plt.legend()
plt.grid(True)

# %%
def predict_test_samples(val_map, model):
  img = val_map['images']
  mask = val_map['masks']

  test_images = np.array(img)

  predictions = model.predict(test_images)

  return predictions,  test_images, mask

# %%
def plot_images(test_image, predicted_maks, ground_truth):
  plt.figure(figsize=(20, 20))

  plt.subplot(1, 3, 1)
  plt.imshow(test_image)
  plt.title('Image')

  plt.subplot(1, 3, 2)
  plt.imshow(predicted_maks)
  plt.title('Predicted mask')

  plt.subplot(1, 3, 3)
  plt.imshow(ground_truth)
  plt.title('Ground truth mask')

# %%
predicted_masks, test_images, ground_truth_masks = predict_test_samples(test_samples, model)

# %%
plot_images(test_images[20], predicted_masks[20], ground_truth_masks[20])
